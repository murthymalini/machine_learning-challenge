# %% [markdown]
# # Image database to Array Database

# %% [markdown]
# ## Sample with one image

# %%
# Import the Image
from tensorflow.keras.preprocessing import image
filepath = "./Images/airport_inside/airport_inside_0001.jpg"
image_size = (1000, 1000)
im = image.load_img(filepath, target_size=image_size, color_mode="grayscale")
im
# Out:
# <PIL.Image.Image image mode=L size=1000x1000 at 0x63F91B5C0>

# %%
# Convert the image to a numpy array 
from tensorflow.keras.preprocessing.image import img_to_array
numpy_image = img_to_array(im)
numpy_image.shape
# Out:
# (1000, 1000, 1)

# %%
# Scale the image pixels by 255 (or use a scaler from sklearn here)
numpy_image /= 255

# Flatten into a 1x1000*1000 array 
img = numpy_image.flatten().reshape(-1, 1000*1000)
img.shape
# Out:
# (1, 1000000)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Invert the pixel values to match the original data
img = 1 - img
plt.imshow(img.reshape(1000, 1000), cmap=plt.cm.Greys)
img
# Out:
# array([[0.12549019, 0.12549019, 0.15686274, ..., 0.5921569 , 0.6392157 ,
#         0.6392157 ]], dtype=float32)

# %%
import os
# Extract the folder name from a path
path = './Images/meeting_room/c_salle8.jpg'

# Get the directory nam from the specified path 
dirname = os.path.dirname(path)
# Replace the initial part of the folder to leave just the folder name
dirname = dirname.replace("./Images/", "")
  
# Print the directory name   
print(dirname)
# Out:
# meeting_room

# %% [markdown]
# ## Loop to transform the database of all images to arrays database

# %%
import os
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import img_to_array

# Path for looking all jpg files
path = './Images/'

# All path files for jpg files contained in the files list
files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.jpg' in file:
            files.append(os.path.join(r, file))

# Use it for testing the code. It limits the files to 10 files
files = files[0:200]

# Convert all images in a Database
X = []
Y = []
for f in files:
    print(f)
    # Import the Image
    filepath = f
    image_size = (1000, 1000)
    im = image.load_img(filepath, target_size=image_size, color_mode="grayscale")
    # Convert the image to a numpy array 
    numpy_image = img_to_array(im)
    # Scale the image pixels by 255 (or use a scaler from sklearn here)
    numpy_image /= 255
    # Flatten into a 1x1000*1000 array 
    img = numpy_image.flatten().reshape(-1, 1000*1000)
    # Invert the pixel values to match the original data
    img = 1 - img
    # Append the image to the database
    X.append(img)
    # Extract the folder name from each path
    # Get the directory name from the specified path 
    dirname = os.path.dirname(filepath)
    # Replace the initial part of the folder to leave just the folder name
    dirname = dirname.replace("./Images/", "")
    Y.append(dirname)
# Out:
# ./Images/meeting_room/c_salle8.jpg
# ./Images/meeting_room/conference3.jpg
# ./Images/meeting_room/pz707.jpg
# ./Images/meeting_room/BoardRoomLG.jpg
# ./Images/meeting_room/coloursenedd_meeting_room_th_2.jpg
# ./Images/meeting_room/central_presidency_room.jpg
# ./Images/meeting_room/P1010088.jpg
# ./Images/meeting_room/salledereunion1.jpg
# ./Images/meeting_room/MagnaDesign_Conference_rectangle_1.jpg
# ./Images/meeting_room/c_labemtgr.jpg
# ./Images/meeting_room/visuel_salle_reunion.jpg
# ./Images/meeting_room/conference2.jpg
# ./Images/meeting_room/c9.jpg
# ./Images/meeting_room/airbus_conference_room.jpg
# ./Images/meeting_room/c18.jpg
# ./Images/meeting_room/Tuinh_Int_01.jpg
# ./Images/meeting_room/c_salle16.jpg
# ./Images/meeting_room/cfsds.jpg
# ./Images/meeting_room/conference1.jpg
# ./Images/meeting_room/n457098.jpg
# ./Images/meeting_room/8365.jpg
# ./Images/meeting_room/meeting_room12.jpg
# ./Images/meeting_room/conference5.jpg
# ./Images/meeting_room/113_bis_meeting_room.jpg
# ./Images/meeting_room/P1010065.jpg
# ./Images/meeting_room/IDC_salle_de_reunion_01.jpg
# ./Images/meeting_room/int200.jpg
# ./Images/meeting_room/P1010070.jpg
# ./Images/meeting_room/11_big.jpg
# ./Images/meeting_room/confd_1.jpg
# ./Images/meeting_room/CHI_011_320x400_web_large.jpg
# ./Images/meeting_room/c20.jpg
# ./Images/meeting_room/meeting_room_ludovisi.jpg
# ./Images/meeting_room/Large_Meeting_Room_sized_down.jpg
# ./Images/meeting_room/conference6.jpg
# ./Images/meeting_room/Art_History_Conference_Room_333.jpg
# ./Images/meeting_room/conference_room.jpg
# ./Images/meeting_room/file_a28580841ed81c4fe168e2cce1ca2750_2.jpg
# ./Images/meeting_room/conference7.jpg
# ./Images/meeting_room/Conference_Room_for_Web.jpg
# ./Images/meeting_room/n457012.jpg
# ./Images/meeting_room/n457006.jpg
# ./Images/meeting_room/gdslab.jpg
# ./Images/meeting_room/050908Library055_1.jpg
# ./Images/meeting_room/Small_meeting_room.jpg
# ./Images/meeting_room/conf25.jpg
# ./Images/meeting_room/conf19.jpg
# ./Images/meeting_room/loca_reunion1.jpg
# ./Images/meeting_room/conference_room_a.jpg
# ./Images/meeting_room/url_2.jpg
# ./Images/meeting_room/b_P1010065.jpg
# ./Images/meeting_room/conf.jpg
# ./Images/meeting_room/Untitled_ds1.jpg
# ./Images/meeting_room/MeyerConferenceRoom.jpg
# ./Images/meeting_room/conf18.jpg
# ./Images/meeting_room/conf24.jpg
# ./Images/meeting_room/n457007.jpg
# ./Images/meeting_room/n457013.jpg
# ./Images/meeting_room/Board_Room.jpg
# ./Images/meeting_room/25_Big.jpg
# ./Images/meeting_room/n457005.jpg
# ./Images/meeting_room/n457011.jpg
# ./Images/meeting_room/n457039.jpg
# ./Images/meeting_room/conf26.jpg
# ./Images/meeting_room/hotel_parque_central_meeting_room_200.jpg
# ./Images/meeting_room/int677.jpg
# ./Images/meeting_room/loca_reunion2.jpg
# ./Images/meeting_room/salle_reunion_suduiraut.jpg
# ./Images/meeting_room/conference_room_4.jpg
# ./Images/meeting_room/b_salle33.jpg
# ./Images/meeting_room/b_salle27.jpg
# ./Images/meeting_room/Library.jpg
# ./Images/meeting_room/conf27.jpg
# ./Images/meeting_room/salle-reunion2.jpg
# ./Images/meeting_room/salle_reunion11.jpg
# ./Images/meeting_room/n457038.jpg
# ./Images/meeting_room/n457010.jpg
# ./Images/meeting_room/n457004.jpg
# ./Images/meeting_room/Conference_Room_Picture.jpg
# ./Images/meeting_room/n457000.jpg
# ./Images/meeting_room/n457014.jpg
# ./Images/meeting_room/c_P1010070.jpg
# ./Images/meeting_room/conf23.jpg
# ./Images/meeting_room/meetingroom3.jpg
# ./Images/meeting_room/sjuntas1.jpg
# ./Images/meeting_room/meeting_room2.jpg
# ./Images/meeting_room/b_salle23.jpg
# ./Images/meeting_room/r_president_hotel_1435_34B.jpg
# ./Images/meeting_room/conference_room_0.jpg
# ./Images/meeting_room/conf22.jpg
# ./Images/meeting_room/confe1.jpg
# ./Images/meeting_room/N457015.jpg
# ./Images/meeting_room/n457001.jpg
# ./Images/meeting_room/brdrm_9870.jpg
# ./Images/meeting_room/n457017.jpg
# ./Images/meeting_room/MagnaDesign_Kaizen_5.jpg
# ./Images/meeting_room/n457003.jpg
# ./Images/meeting_room/confer.jpg
# ./Images/meeting_room/conf08.jpg
# ./Images/meeting_room/conf20.jpg
# ./Images/meeting_room/pdc_meeting_room_l.jpg
# ./Images/meeting_room/conference_room_2.jpg
# ./Images/meeting_room/meeting_room1.jpg
# ./Images/meeting_room/Connect_Open_Conference.jpg
# ./Images/meeting_room/Conference Room.jpg
# ./Images/meeting_room/senate_conf_room.jpg
# ./Images/meeting_room/conference.jpg
# ./Images/meeting_room/lhom9b.jpg
# ./Images/meeting_room/conf21.jpg
# ./Images/meeting_room/conf09.jpg
# ./Images/meeting_room/n457002.jpg
# ./Images/meeting_room/confrm.jpg
# ./Images/meeting_room/Meeting_RoomLG_1_.jpg
# ./Images/meeting_room/meet10_450.jpg
# ./Images/meeting_room/conf04.jpg
# ./Images/meeting_room/conf10.jpg
# ./Images/meeting_room/central_meeting_room.jpg
# ./Images/meeting_room/Renovated_Meeting_Room.jpg
# ./Images/meeting_room/b_P1010087.jpg
# ./Images/meeting_room/cnsgs.jpg
# ./Images/meeting_room/Conference_640x480.jpg
# ./Images/meeting_room/room291.jpg
# ./Images/meeting_room/n_conference_room_lg.jpg
# ./Images/meeting_room/conf11.jpg
# ./Images/meeting_room/conference_room1.jpg
# ./Images/meeting_room/conf05.jpg
# ./Images/meeting_room/salle_reunion33.jpg
# ./Images/meeting_room/Midsize_Conference_Room.jpg
# ./Images/meeting_room/08.jpg
# ./Images/meeting_room/salle_de_reunion.jpg
# ./Images/meeting_room/n457018.jpg
# ./Images/meeting_room/conf13.jpg
# ./Images/meeting_room/conference_room_1_lr_sm.jpg
# ./Images/meeting_room/conf07.jpg
# ./Images/meeting_room/meeting_room1_1.jpg
# ./Images/meeting_room/slusser_big.jpg
# ./Images/meeting_room/Salle_reunion2.jpg
# ./Images/meeting_room/conference_room_600.jpg
# ./Images/meeting_room/Renovated_Meeting_Room_2.jpg
# ./Images/meeting_room/int864.jpg
# ./Images/meeting_room/Conference_Hotel_Trinite_Plaza_France.jpg
# ./Images/meeting_room/conf06.jpg
# ./Images/meeting_room/conference_room2.jpg
# ./Images/meeting_room/therapy_unit_meeting_room.jpg
# ./Images/meeting_room/conferencerm2_gif.jpg
# ./Images/meeting_room/conf12.jpg
# ./Images/meeting_room/n457019.jpg
# ./Images/meeting_room/n457009.jpg
# ./Images/meeting_room/n457021.jpg
# ./Images/meeting_room/conf16.jpg
# ./Images/meeting_room/conf02.jpg
# ./Images/meeting_room/Conference-room.jpg
# ./Images/meeting_room/file_001ad55a7d61f942cb9bb884711790d5.jpg
# ./Images/meeting_room/Meeting_Room_1_3.jpg
# ./Images/meeting_room/conference-room1.jpg
# ./Images/meeting_room/conf03.jpg
# ./Images/meeting_room/conf17.jpg
# ./Images/meeting_room/n457020.jpg
# ./Images/meeting_room/salle_reunion21.jpg
# ./Images/meeting_room/n457008.jpg
# ./Images/meeting_room/salle_reunion443.jpg
# ./Images/meeting_room/P2040009.jpg
# ./Images/meeting_room/n457022.jpg
# ./Images/meeting_room/salle_reunion133.jpg
# ./Images/meeting_room/conf01.jpg
# ./Images/meeting_room/conf15.jpg
# ./Images/meeting_room/ph_Meetings.jpg
# ./Images/meeting_room/int283.jpg
# ./Images/meeting_room/b_P1010082.jpg
# ./Images/meeting_room/salle_reunion_1.jpg
# ./Images/meeting_room/MeetingRoom55.jpg
# ./Images/meeting_room/room451.jpg
# ./Images/meeting_room/c_P1010084.jpg
# ./Images/meeting_room/conf14.jpg
# ./Images/meeting_room/conference_room4.jpg
# ./Images/meeting_room/conf28.jpg
# ./Images/meeting_room/meeting_room.jpg
# ./Images/meeting_room/n457037.jpg
# ./Images/meeting_room/0LG_0006_Layer_3.jpg
# ./Images/meeting_room/c1.jpg
# ./Images/meeting_room/c12.jpg
# ./Images/meeting_room/cf1.jpg
# ./Images/meeting_room/P1010081.jpg
# ./Images/meeting_room/chateau_salle_conference01.jpg
# ./Images/meeting_room/Conference room2.jpg
# ./Images/meeting_room/Cadman_Conf_Room_tcm68_19265.jpg
# ./Images/meeting_room/salon_jaune.jpg
# ./Images/meeting_room/ins28.jpg
# ./Images/meeting_room/MeetingRoom.jpg
# ./Images/meeting_room/meeting1.jpg
# ./Images/meeting_room/c13.jpg
# ./Images/meeting_room/c2.jpg
# ./Images/meeting_room/c_salle2.jpg
# ./Images/meeting_room/BoardRoom.jpg
# ./Images/meeting_room/c11.jpg
# ./Images/meeting_room/Conference_room567.jpg
# ./Images/meeting_room/Large_0004_Layer_4.jpg
# ./Images/meeting_room/MeetingRoom25.jpg
# ./Images/meeting_room/AgoraPhotoSalleDeReunion.jpg
# ./Images/meeting_room/tc_conference_room.jpg

# %%
# Test X
X
# Out:
#  dtype=float32),
#  array([[0.05882353, 0.05098039, 0.03529412, ..., 0.6431372 , 0.6431372 ,
#          0.6392157 ]], dtype=float32),
#  array([[0.5058824, 0.5058824, 0.5058824, ..., 0.827451 , 0.827451 ,
#          0.827451 ]], dtype=float32),
#  array([[0.16470587, 0.16470587, 0.16862744, ..., 0.9882353 , 0.9882353 ,
#          0.9882353 ]], dtype=float32),
#  array([[0.5294118 , 0.5764706 , 0.60392153, ..., 0.25490195, 0.21568626,
#          0.1607843 ]], dtype=float32),
#  array([[0.4352941 , 0.4352941 , 0.43921566, ..., 0.89411765, 0.8901961 ,
#          0.8901961 ]], dtype=float32),
#  array([[0.33725488, 0.33725488, 0.33725488, ..., 0.54509807, 0.54509807,
#          0.54509807]], dtype=float32),
#  array([[0.4705882 , 0.46274507, 0.4588235 , ..., 0.8156863 , 0.8392157 ,
#          0.84313726]], dtype=float32),
#  array([[0.8784314, 0.8784314, 0.8627451, ..., 0.6862745, 0.7215686,
#          0.7215686]], dtype=float32),
#  array([[0.34509802, 0.34509802, 0.34509802, ..., 0.21960783, 0.21960783,
#          0.21960783]], dtype=float32),
#  array([[0.9490196 , 0.9490196 , 0.94509804, ..., 0.9647059 , 0.9647059 ,
#          0.9647059 ]], dtype=float32),
#  array([[0.09803921, 0.09803921, 0.09803921, ..., 0.6431372 , 0.6431372 ,
#          0.6431372 ]], dtype=float32),
#  array([[0.52549016, 0.52549016, 0.52549016, ..., 0.7058823 , 0.7019608 ,
#          0.7019608 ]], dtype=float32),
#  array([[0.36862743, 0.36862743, 0.36470586, ..., 0.745098  , 0.73333335,
#          0.73333335]], dtype=float32),
#  array([[0.56078434, 0.56470585, 0.56470585, ..., 0.5294118 , 0.6156863 ,
#          0.654902  ]], dtype=float32),
#  array([[0.3215686, 0.3215686, 0.3215686, ..., 0.7921569, 0.7921569,
#          0.7921569]], dtype=float32),
#  array([[0.       , 0.       , 0.       , ..., 0.6      , 0.6352941,
#          0.6588235]], dtype=float32),
#  array([[0.58431375, 0.58431375, 0.62352943, ..., 0.7411765 , 0.7607843 ,
#          0.7607843 ]], dtype=float32),
#  array([[0.6823529, 0.6823529, 0.6823529, ..., 0.8980392, 0.9019608,
#          0.9019608]], dtype=float32),
#  array([[0.77254903, 0.77254903, 0.77254903, ..., 0.7529412 , 0.7529412 ,
#          0.7529412 ]], dtype=float32),
#  array([[0.60784316, 0.60784316, 0.60784316, ..., 0.4588235 , 0.4588235 ,
#          0.4588235 ]], dtype=float32),
#  array([[0.5294118 , 0.5294118 , 0.5294118 , ..., 0.81960785, 0.81960785,
#          0.81960785]], dtype=float32),
#  array([[0.78039217, 0.78039217, 0.8156863 , ..., 0.92156863, 0.92156863,
#          0.9254902 ]], dtype=float32),
#  array([[0.37647057, 0.38823527, 0.37647057, ..., 0.8       , 0.8117647 ,
#          0.78431374]], dtype=float32),
#  array([[0.2235294 , 0.2235294 , 0.21568626, ..., 0.81960785, 0.79607844,
#          0.79607844]], dtype=float32),
#  array([[0.7019608 , 0.7019608 , 0.7019608 , ..., 0.43137252, 0.43137252,
#          0.43137252]], dtype=float32),
#  array([[0.572549 , 0.572549 , 0.572549 , ..., 0.7254902, 0.7254902,
#          0.7254902]], dtype=float32),
#  array([[0.25490195, 0.2588235 , 0.25490195, ..., 0.77254903, 0.7882353 ,
#          0.7921569 ]], dtype=float32),
#  array([[0.01960784, 0.01960784, 0.01960784, ..., 0.02745098, 0.02745098,
#          0.02745098]], dtype=float32),
#  array([[0.7882353 , 0.7882353 , 0.76862746, ..., 0.7215686 , 0.73333335,
#          0.73333335]], dtype=float32),
#  array([[0.5764706 , 0.5764706 , 0.5764706 , ..., 0.48627448, 0.48627448,
#          0.48627448]], dtype=float32),
#  array([[0.7647059 , 0.77254903, 0.7529412 , ..., 0.67450976, 0.6666666 ,
#          0.65098035]], dtype=float32),
#  array([[0.47450978, 0.47450978, 0.47450978, ..., 0.90588236, 0.90588236,
#          0.90588236]], dtype=float32),
#  array([[0.12156862, 0.12156862, 0.11764705, ..., 0.7019608 , 0.71372545,
#          0.71372545]], dtype=float32),
#  array([[0.77254903, 0.77254903, 0.77254903, ..., 0.6313726 , 0.6313726 ,
#          0.6313726 ]], dtype=float32),
#  array([[0.79607844, 0.79607844, 0.79607844, ..., 0.00784314, 0.00784314,
#          0.00784314]], dtype=float32),
#  array([[0.4705882, 0.4705882, 0.4705882, ..., 0.8901961, 0.8901961,
#          0.8901961]], dtype=float32),
#  array([[0.8392157 , 0.8392157 , 0.8392157 , ..., 0.73333335, 0.73333335,
#          0.73333335]], dtype=float32),
#  array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  array([[0.54117644, 0.5333333 , 0.5294118 , ..., 0.6392157 , 0.6313726 ,
#          0.6431372 ]], dtype=float32),
#  array([[0.4980392, 0.4980392, 0.4980392, ..., 0.9764706, 0.9764706,
#          0.9764706]], dtype=float32),
#  array([[0.69019604, 0.69019604, 0.69019604, ..., 0.64705884, 0.64705884,
#          0.64705884]], dtype=float32),
#  array([[0.48627448, 0.48627448, 0.48627448, ..., 0.5372549 , 0.5372549 ,
#          0.5372549 ]], dtype=float32),
#  array([[0.5058824, 0.5058824, 0.5058824, ..., 0.4823529, 0.4823529,
#          0.4823529]], dtype=float32),
#  array([[0.49411762, 0.49411762, 0.49411762, ..., 0.7647059 , 0.7647059 ,
#          0.7647059 ]], dtype=float32),
#  array([[0.61176467, 0.61176467, 0.61176467, ..., 0.65098035, 0.65098035,
#          0.65098035]], dtype=float32),
#  array([[0.61176467, 0.5764706 , 0.58431375, ..., 0.572549  , 0.5960784 ,
#          0.61176467]], dtype=float32),
#  array([[0.6627451, 0.6627451, 0.6627451, ..., 0.6      , 0.6      ,
#          0.6      ]], dtype=float32),
#  array([[0.827451  , 0.78431374, 0.78431374, ..., 0.9607843 , 0.9607843 ,
#          0.93333334]], dtype=float32),
#  array([[0.52549016, 0.52549016, 0.52549016, ..., 0.5137255 , 0.5137255 ,
#          0.5137255 ]], dtype=float32),
#  array([[0.36470586, 0.36470586, 0.36470586, ..., 0.9411765 , 0.9411765 ,
#          0.9411765 ]], dtype=float32),
#  array([[0.5294118 , 0.5294118 , 0.5294118 , ..., 0.78431374, 0.7921569 ,
#          0.7921569 ]], dtype=float32),
#  array([[0.4705882, 0.4705882, 0.4705882, ..., 0.9019608, 0.9019608,
#          0.9019608]], dtype=float32),
#  array([[0.8980392 , 0.8980392 , 0.88235295, ..., 0.7882353 , 0.79607844,
#          0.79607844]], dtype=float32),
#  array([[0.3843137 , 0.3843137 , 0.3843137 , ..., 0.30588233, 0.28235292,
#          0.28235292]], dtype=float32),
#  array([[0.4588235 , 0.4588235 , 0.4588235 , ..., 0.87058824, 0.87058824,
#          0.87058824]], dtype=float32),
#  array([[0.16862744, 0.16862744, 0.16862744, ..., 0.5803921 , 0.5803921 ,
#          0.5803921 ]], dtype=float32),
#  array([[0.4470588, 0.4470588, 0.4470588, ..., 0.6588235, 0.6588235,
#          0.6588235]], dtype=float32),
#  array([[0.8117647, 0.8117647, 0.8117647, ..., 0.8745098, 0.8745098,
#          0.8745098]], dtype=float32),
#  array([[0.09411764, 0.09411764, 0.09411764, ..., 0.54117644, 0.54117644,
#          0.54117644]], dtype=float32),
#  array([[0.28235292, 0.28235292, 0.28235292, ..., 0.517647  , 0.517647  ,
#          0.517647  ]], dtype=float32),
#  array([[0.5137255, 0.5137255, 0.5137255, ..., 0.7411765, 0.7411765,
#          0.7411765]], dtype=float32),
#  array([[0.7490196, 0.7490196, 0.7490196, ..., 0.9529412, 0.9529412,
#          0.9529412]], dtype=float32),
#  array([[0.2352941 , 0.2352941 , 0.2352941 , ..., 0.41960782, 0.41960782,
#          0.41960782]], dtype=float32),
#  array([[0.7176471 , 0.7176471 , 0.7215686 , ..., 0.87058824, 0.8627451 ,
#          0.8627451 ]], dtype=float32),
#  array([[0.61176467, 0.5764706 , 0.58431375, ..., 0.572549  , 0.5960784 ,
#          0.61176467]], dtype=float32),
#  array([[0.2980392 , 0.2980392 , 0.2980392 , ..., 0.52549016, 0.52549016,
#          0.52549016]], dtype=float32),
#  array([[0.5529412 , 0.5529412 , 0.5529412 , ..., 0.11764705, 0.11764705,
#          0.11764705]], dtype=float32),
#  array([[0.5529412 , 0.5529412 , 0.5529412 , ..., 0.7921569 , 0.7921569 ,
#          0.79607844]], dtype=float32),
#  array([[0.48627448, 0.48627448, 0.48627448, ..., 0.60392153, 0.60392153,
#          0.60392153]], dtype=float32),
#  array([[0.52156866, 0.52156866, 0.517647  , ..., 0.7490196 , 0.7529412 ,
#          0.7529412 ]], dtype=float32),
#  array([[0.6196078, 0.6196078, 0.6196078, ..., 0.9882353, 0.9882353,
#          0.9882353]], dtype=float32),
#  array([[0.26666665, 0.26666665, 0.26666665, ..., 0.58823526, 0.58823526,
#          0.58823526]], dtype=float32),
#  array([[0.17254901, 0.17254901, 0.18823528, ..., 0.827451  , 0.8       ,
#          0.8       ]], dtype=float32),
#  array([[0.3843137 , 0.3843137 , 0.3843137 , ..., 0.65098035, 0.65098035,
#          0.65098035]], dtype=float32),
#  array([[0.56470585, 0.56470585, 0.56078434, ..., 0.84313726, 0.84313726,
#          0.8392157 ]], dtype=float32),
#  array([[0.46274507, 0.46274507, 0.46274507, ..., 0.5333333 , 0.5333333 ,
#          0.5333333 ]], dtype=float32),
#  array([[0.23137254, 0.23137254, 0.23137254, ..., 0.4235294 , 0.4235294 ,
#          0.4235294 ]], dtype=float32),
#  array([[0.6       , 0.6       , 0.6       , ..., 0.88235295, 0.88235295,
#          0.88235295]], dtype=float32),
#  array([[0.41960782, 0.41960782, 0.41960782, ..., 0.5803921 , 0.5803921 ,
#          0.5803921 ]], dtype=float32),
#  array([[0.58823526, 0.5529412 , 0.50196075, ..., 0.80784315, 0.80784315,
#          0.8235294 ]], dtype=float32),
#  array([[0.6784314 , 0.6784314 , 0.6823529 , ..., 0.6313726 , 0.67058825,
#          0.67058825]], dtype=float32),
#  array([[0.25490195, 0.2588235 , 0.25490195, ..., 0.77254903, 0.7882353 ,
#          0.7921569 ]], dtype=float32),
#  array([[0.43921566, 0.43921566, 0.43921566, ..., 0.60784316, 0.60784316,
#          0.60784316]], dtype=float32),
#  array([[0.654902  , 0.654902  , 0.65098035, ..., 0.78039217, 0.7647059 ,
#          0.7647059 ]], dtype=float32),
#  array([[0.5294118, 0.5294118, 0.5294118, ..., 0.8666667, 0.8666667,
#          0.8666667]], dtype=float32),
#  array([[0.73333335, 0.73333335, 0.27843136, ..., 0.2117647 , 0.2117647 ,
#          0.2117647 ]], dtype=float32),
#  array([[0.6588235 , 0.6588235 , 0.6627451 , ..., 0.47450978, 0.47843134,
#          0.47843134]], dtype=float32),
#  array([[0.5058824, 0.5058824, 0.5058824, ..., 0.3607843, 0.3607843,
#          0.3607843]], dtype=float32),
#  array([[0.00392157, 0.00392157, 0.00392157, ..., 0.4352941 , 0.4352941 ,
#          0.4352941 ]], dtype=float32),
#  array([[0.3607843, 0.3607843, 0.3607843, ..., 0.9490196, 0.9490196,
#          0.9490196]], dtype=float32),
#  array([[0.52549016, 0.52549016, 0.6       , ..., 0.5137255 , 0.6196078 ,
#          0.6196078 ]], dtype=float32),
#  array([[0.54509807, 0.54509807, 0.54509807, ..., 0.98039216, 0.98039216,
#          0.98039216]], dtype=float32),
#  array([[0.5803921 , 0.5803921 , 0.58431375, ..., 0.42745095, 0.4470588 ,
#          0.4470588 ]], dtype=float32),
#  array([[0.22745097, 0.22745097, 0.22745097, ..., 0.65098035, 0.65098035,
#          0.65098035]], dtype=float32),
#  array([[0.00392157, 0.00392157, 0.00392157, ..., 0.64705884, 0.64705884,
#          0.64705884]], dtype=float32),
#  array([[0.2352941 , 0.2352941 , 0.24313724, ..., 0.4980392 , 0.49411762,
#          0.49411762]], dtype=float32),
#  array([[0.4980392 , 0.5294118 , 0.5490196 , ..., 0.62352943, 0.6196078 ,
#          0.6       ]], dtype=float32),
#  array([[0.26666665, 0.26666665, 0.26666665, ..., 0.9372549 , 0.9372549 ,
#          0.9372549 ]], dtype=float32),
#  array([[0.32941175, 0.32941175, 0.32941175, ..., 0.7215686 , 0.7215686 ,
#          0.7215686 ]], dtype=float32),
#  array([[0.5058824, 0.5058824, 0.5058824, ..., 0.827451 , 0.827451 ,
#          0.827451 ]], dtype=float32),
#  array([[0.52156866, 0.52156866, 0.52156866, ..., 0.8       , 0.8       ,
#          0.8       ]], dtype=float32),
#  array([[0.5098039 , 0.5098039 , 0.5529412 , ..., 0.69019604, 0.6392157 ,
#          0.6392157 ]], dtype=float32),
#  array([[0.49411762, 0.49411762, 0.49411762, ..., 0.6392157 , 0.6392157 ,
#          0.6392157 ]], dtype=float32),
#  array([[0.46666664, 0.46666664, 0.46666664, ..., 0.8352941 , 0.8352941 ,
#          0.8352941 ]], dtype=float32),
#  array([[0.47450978, 0.47450978, 0.47450978, ..., 0.9137255 , 0.9137255 ,
#          0.9137255 ]], dtype=float32),
#  array([[0.2745098 , 0.2745098 , 0.2745098 , ..., 0.69019604, 0.69019604,
#          0.69019604]], dtype=float32),
#  array([[0.5529412, 0.5529412, 0.5529412, ..., 0.8156863, 0.8156863,
#          0.8156863]], dtype=float32),
#  array([[0.84313726, 0.84313726, 0.84313726, ..., 0.80784315, 0.8235294 ,
#          0.8235294 ]], dtype=float32),
#  array([[0.654902  , 0.654902  , 0.76862746, ..., 0.8627451 , 0.9098039 ,
#          0.9098039 ]], dtype=float32),
#  array([[0.84313726, 0.84313726, 0.84313726, ..., 0.5137255 , 0.5137255 ,
#          0.5137255 ]], dtype=float32),
#  array([[0.44313723, 0.44313723, 0.44313723, ..., 0.54509807, 0.54509807,
#          0.54509807]], dtype=float32),
#  array([[0.83137256, 0.8392157 , 0.8352941 , ..., 0.9254902 , 0.9372549 ,
#          0.9490196 ]], dtype=float32),
#  array([[0.5058824, 0.5058824, 0.5058824, ..., 0.6431372, 0.6431372,
#          0.6431372]], dtype=float32),
#  array([[0.56078434, 0.56078434, 0.56078434, ..., 0.9254902 , 0.9254902 ,
#          0.9254902 ]], dtype=float32),
#  array([[0.6784314 , 0.6784314 , 0.7411765 , ..., 0.83137256, 0.81960785,
#          0.81960785]], dtype=float32),
#  array([[0.20392156, 0.20392156, 0.20392156, ..., 0.6313726 , 0.6313726 ,
#          0.6313726 ]], dtype=float32),
#  array([[0.16862744, 0.16862744, 0.16862744, ..., 0.6431372 , 0.6666666 ,
#          0.6666666 ]], dtype=float32),
#  array([[0.517647  , 0.5137255 , 0.5137255 , ..., 0.79607844, 0.79607844,
#          0.8       ]], dtype=float32),
#  array([[0.25098038, 0.25098038, 0.25098038, ..., 0.78039217, 0.78039217,
#          0.78039217]], dtype=float32),
#  array([[1.        , 1.        , 1.        , ..., 0.99607843, 0.99607843,
#          0.99607843]], dtype=float32),
#  array([[0.41568625, 0.41568625, 0.41568625, ..., 0.73725486, 0.73725486,
#          0.73725486]], dtype=float32),
#  array([[0.29411763, 0.29411763, 0.2862745 , ..., 0.81960785, 0.81960785,
#          0.81960785]], dtype=float32),
#  array([[0.67450976, 0.67450976, 0.67450976, ..., 0.9019608 , 0.9019608 ,
#          0.9019608 ]], dtype=float32),
#  array([[0.        , 0.        , 0.        , ..., 0.15686274, 0.15686274,
#          0.15686274]], dtype=float32),
#  array([[0.44313723, 0.44313723, 0.44313723, ..., 0.98039216, 0.98039216,
#          0.98039216]], dtype=float32),
#  array([[0.56470585, 0.56470585, 0.56470585, ..., 0.4470588 , 0.4470588 ,
#          0.4470588 ]], dtype=float32),
#  array([[0.9764706 , 0.9764706 , 0.9764706 , ..., 0.61176467, 0.61176467,
#          0.61176467]], dtype=float32),
#  array([[0.58823526, 0.58823526, 0.58823526, ..., 0.40392154, 0.40392154,
#          0.40392154]], dtype=float32),
#  array([[0.6313726, 0.6313726, 0.6313726, ..., 0.7764706, 0.7764706,
#          0.7764706]], dtype=float32),
#  array([[0.6      , 0.6      , 0.6      , ..., 0.7294117, 0.7294117,
#          0.7294117]], dtype=float32),
#  array([[0.65098035, 0.65098035, 0.654902  , ..., 0.43921566, 0.44313723,
#          0.44313723]], dtype=float32),
#  array([[0.4980392, 0.4980392, 0.4980392, ..., 0.7294117, 0.7294117,
#          0.7294117]], dtype=float32),
#  array([[0.75686276, 0.7647059 , 0.7647059 , ..., 0.5686275 , 0.5686275 ,
#          0.58431375]], dtype=float32),
#  array([[0.0745098 , 0.0745098 , 0.07058823, ..., 0.47843134, 0.92941177,
#          0.92941177]], dtype=float32),
#  array([[0.64705884, 0.64705884, 0.64705884, ..., 0.7215686 , 0.7215686 ,
#          0.7215686 ]], dtype=float32),
#  array([[0.5960784 , 0.5960784 , 0.5960784 , ..., 0.73725486, 0.73725486,
#          0.73725486]], dtype=float32),
#  array([[0.54509807, 0.54509807, 0.54509807, ..., 0.95686275, 0.95686275,
#          0.95686275]], dtype=float32),
#  array([[0.58431375, 0.60392153, 0.6196078 , ..., 0.6       , 0.5960784 ,
#          0.5921569 ]], dtype=float32),
#  array([[0.9647059, 0.9647059, 0.9647059, ..., 0.9137255, 0.9137255,
#          0.9137255]], dtype=float32),
#  array([[0.4352941 , 0.4352941 , 0.4352941 , ..., 0.30588233, 0.30588233,
#          0.30588233]], dtype=float32),
#  array([[0.09803921, 0.09411764, 0.09803921, ..., 0.7215686 , 0.7176471 ,
#          0.7215686 ]], dtype=float32),
#  array([[0.88235295, 0.88235295, 0.88235295, ..., 0.41568625, 0.41568625,
#          0.41568625]], dtype=float32),
#  array([[0.49411762, 0.49411762, 0.48627448, ..., 0.7215686 , 0.7215686 ,
#          0.7215686 ]], dtype=float32),
#  array([[0.5764706 , 0.5764706 , 0.5764706 , ..., 0.84705883, 0.84705883,
#          0.84705883]], dtype=float32),
#  array([[0.87058824, 0.87058824, 0.87058824, ..., 0.26274508, 0.26274508,
#          0.26274508]], dtype=float32),
#  array([[0.41568625, 0.41568625, 0.41568625, ..., 0.8509804 , 0.8392157 ,
#          0.8392157 ]], dtype=float32),
#  array([[0.05882353, 0.05882353, 0.05882353, ..., 0.88235295, 0.88235295,
#          0.88235295]], dtype=float32),
#  array([[0.372549 , 0.372549 , 0.372549 , ..., 0.8235294, 0.8235294,
#          0.8235294]], dtype=float32),
#  array([[0.00392157, 0.00392157, 0.00392157, ..., 0.38039213, 0.38039213,
#          0.38039213]], dtype=float32),
#  array([[0.00784314, 0.00784314, 0.00784314, ..., 0.95686275, 0.95686275,
#          0.95686275]], dtype=float32),
#  array([[0.47843134, 0.47843134, 0.47843134, ..., 0.93333334, 0.93333334,
#          0.93333334]], dtype=float32),
#  array([[0.31764704, 0.31764704, 0.31764704, ..., 0.9607843 , 0.9607843 ,
#          0.9607843 ]], dtype=float32),
#  array([[0.28235292, 0.28235292, 0.28235292, ..., 0.64705884, 0.64705884,
#          0.64705884]], dtype=float32),
#  array([[0.49019605, 0.49019605, 0.47843134, ..., 0.7921569 , 0.7882353 ,
#          0.7921569 ]], dtype=float32),
#  array([[0.75686276, 0.75686276, 0.75686276, ..., 0.9098039 , 0.9098039 ,
#          0.9098039 ]], dtype=float32),
#  array([[0.5333333, 0.5333333, 0.572549 , ..., 0.7529412, 0.7529412,
#          0.7529412]], dtype=float32),
#  array([[0.62745094, 0.62745094, 0.62745094, ..., 0.7176471 , 0.7176471 ,
#          0.7176471 ]], dtype=float32),
#  array([[0.25490195, 0.25490195, 0.25490195, ..., 0.88235295, 0.88235295,
#          0.88235295]], dtype=float32),
#  array([[0.62352943, 0.62352943, 0.62352943, ..., 0.96862745, 0.96862745,
#          0.96862745]], dtype=float32),
#  array([[0.1607843, 0.1607843, 0.1607843, ..., 0.8352941, 0.8352941,
#          0.8352941]], dtype=float32),
#  array([[0.18823528, 0.18823528, 0.18823528, ..., 0.58823526, 0.58823526,
#          0.58823526]], dtype=float32),
#  array([[0.6627451 , 0.65098035, 0.6588235 , ..., 0.8784314 , 0.8392157 ,
#          0.84313726]], dtype=float32),
#  array([[0.6431372, 0.6431372, 0.6431372, ..., 0.9607843, 0.9607843,
#          0.9607843]], dtype=float32),
#  array([[0.46274507, 0.46274507, 0.46666664, ..., 0.21568626, 0.00392157,
#          0.00392157]], dtype=float32),
#  array([[0.41960782, 0.41568625, 0.4078431 , ..., 0.5137255 , 0.5058824 ,
#          0.4980392 ]], dtype=float32),
#  array([[0.46666664, 0.46666664, 0.47450978, ..., 0.6431372 , 0.69411767,
#          0.69411767]], dtype=float32),
#  array([[0.83137256, 0.83137256, 0.83137256, ..., 0.6823529 , 0.6823529 ,
#          0.6823529 ]], dtype=float32),
#  array([[0.745098  , 0.745098  , 0.745098  , ..., 0.5098039 , 0.49019605,
#          0.49019605]], dtype=float32),
#  array([[0.31764704, 0.31764704, 0.31764704, ..., 0.99607843, 0.99607843,
#          0.99607843]], dtype=float32),
#  array([[0.31372547, 0.31372547, 0.31372547, ..., 0.52156866, 0.52156866,
#          0.52156866]], dtype=float32),
#  array([[0.73725486, 0.73725486, 0.73725486, ..., 0.46666664, 0.46666664,
#          0.46666664]], dtype=float32),
#  array([[0.18431371, 0.18431371, 0.18431371, ..., 0.8980392 , 0.8980392 ,
#          0.8980392 ]], dtype=float32),
#  array([[0.3215686 , 0.3215686 , 0.3215686 , ..., 0.60392153, 0.60392153,
#          0.60392153]], dtype=float32),
#  array([[0.58431375, 0.58431375, 0.58431375, ..., 0.89411765, 0.89411765,
#          0.89411765]], dtype=float32),
#  array([[0.3607843 , 0.3607843 , 0.3607843 , ..., 0.58823526, 0.58823526,
#          0.58823526]], dtype=float32),
#  array([[0.5058824, 0.5058824, 0.5058824, ..., 0.9254902, 0.9254902,
#          0.9254902]], dtype=float32),
#  array([[0.4705882 , 0.36470586, 0.36862743, ..., 0.9137255 , 0.90588236,
#          0.89411765]], dtype=float32),
#  array([[0.7294117 , 0.7294117 , 0.7254902 , ..., 0.93333334, 0.93333334,
#          0.93333334]], dtype=float32),
#  array([[0.32941175, 0.3333333 , 0.3333333 , ..., 0.67058825, 0.67058825,
#          0.6784314 ]], dtype=float32)]

# %%
# Test Y
Y
# Out:
# ['meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room',
#  'meeting_room']
